# %% [markdown]
# ----
# # Extract the Paths from the SVG

# %%
# Extract the paths from the SVG
import xml.etree.ElementTree as et
import pandas as pd

file_path = r'C:\Users\daveb\OneDrive\Documents\GitHub\StatsByCountry\saves\svg\BlankMap-World_save_as.svg'
root = et.parse(file_path).getroot()
rows_list = []
for el in root.iter():
    rows_list.append(el.attrib)
df = pd.DataFrame(rows_list).rename(columns={
    'width': 'svg_width',
    '{http://www.inkscape.org/namespaces/inkscape}version': 'inkscape_version',
    'height': 'svg_height',
    'id': 'svg_id',
    '{http://sodipodi.sourceforge.net/DTD/sodipodi-0.dtd}docname': 'sodipodi_docname',
    'version': 'svg_version',
    'viewBox': 'svg_viewBox',
    'bordercolor': 'svg_bordercolor',
    'borderopacity': 'svg_borderopacity',
    '{http://www.inkscape.org/namespaces/inkscape}current-layer': 'inkscape_current_layer',
    '{http://www.inkscape.org/namespaces/inkscape}cx': 'inkscape_cx',
    '{http://www.inkscape.org/namespaces/inkscape}cy': 'inkscape_cy',
    '{http://www.inkscape.org/namespaces/inkscape}pagecheckerboard': 'inkscape_pagecheckerboard',
    '{http://www.inkscape.org/namespaces/inkscape}pageopacity': 'inkscape_pageopacity',
    '{http://www.inkscape.org/namespaces/inkscape}pageshadow': 'inkscape_pageshadow',
    '{http://www.inkscape.org/namespaces/inkscape}window-height': 'inkscape_window_height',
    '{http://www.inkscape.org/namespaces/inkscape}window-maximized': 'inkscape_window_maximized',
    '{http://www.inkscape.org/namespaces/inkscape}window-width': 'inkscape_window_width',
    '{http://www.inkscape.org/namespaces/inkscape}window-x': 'inkscape_window_x',
    '{http://www.inkscape.org/namespaces/inkscape}window-y': 'inkscape_window_y',
    '{http://www.inkscape.org/namespaces/inkscape}zoom': 'inkscape_zoom',
    'pagecolor': 'svg_pagecolor',
    'showgrid': 'svg_showgrid',
    'type': 'svg_type',
    'd': 'svg_d',
    'style': 'svg_style',
    '{http://www.inkscape.org/namespaces/inkscape}connector-curvature': 'inkscape_connector_curvature',
    '{http://www.w3.org/1999/02/22-rdf-syntax-ns#}about': 'rdf_about',
    '{http://www.w3.org/1999/02/22-rdf-syntax-ns#}resource': 'rdf_resource',
    'x': 'svg_x',
    'y': 'svg_y',
    '{http://www.inkscape.org/namespaces/inkscape}label': 'inkscape_label',
    '{http://sodipodi.sourceforge.net/DTD/sodipodi-0.dtd}insensitive': 'sodipodi_insensitive',
    'data-id': 'svg_data_id',
    'data-name': 'svg_data_name',
    '{http://sodipodi.sourceforge.net/DTD/sodipodi-0.dtd}role': 'sodipodi_role',
    'r': 'circle_radius',
    'cx': 'center_x',
    'cy': 'center_y',
    'class': 'path_class'})

# %%
import sys

# Insert at 1, 0 is the script path (or '' in REPL)
sys.path.insert(1, '../py')

from storage import Storage
from stats_scraping_utils import StatsScrapingUtilities

s = Storage()
ssu = StatsScrapingUtilities(s=s)
column_descriptions_df = ssu.get_column_descriptions(df, column_list=None)

# %%
column_descriptions_df.sort_values(['count_uniques'], ascending=[False])
# Out:
#                   column_name   dtype  count_blanks  count_uniques  \
# 3                      svg_id  object             3           2874
# 24                      svg_d  object           663           2212
# 23                 path_class  object          2446            421
# 27                   center_x  object          2773            101
# 26                   center_y  object          2773            101
# 25              circle_radius  object          2773              6
# 0                 svg_version  object          2875              2
# 15                inkscape_cy  object          2875              2
# 22                   svg_type  object          2875              2
# 21     inkscape_current_layer  object          2875              2
# 20  inkscape_window_maximized  object          2875              2
# 19          inkscape_window_y  object          2875              2
# 18          inkscape_window_x  object          2875              2
# 17     inkscape_window_height  object          2875              2
# 16      inkscape_window_width  object          2875              2
# 14                inkscape_cx  object          2875              2
# 1                   svg_width  object          2875              2
# 13              inkscape_zoom  object          2875              2
# 12               svg_showgrid  object          2875              2
# 11  inkscape_pagecheckerboard  object          2875              2
# 10       inkscape_pageopacity  object          2875              2
# 9         inkscape_pageshadow  object          2875              2
# 8           svg_borderopacity  object          2875              2
# 7             svg_bordercolor  object          2875              2
# 6               svg_pagecolor  object          2875              2
# 5            inkscape_version  object          2875              2
# 4            sodipodi_docname  object          2875              2
# 2                  svg_height  object          2875              2
# 28                  rdf_about  object          2875              2
#
#     count_zeroes  has_dates                                        min_value  \
# 3              0      False                                   Angola_Cabinda
# 24             0      False  m 1005.94,815.96 c 1.08,-2.827 -1.86,-0.525 0,0
# 23             0      False                          antxx landxx coastxx aq
# 27             0       True                                              101
# 26             0      False                                          1123.85
# 25             0      False                                             0.25
# 0              0      False                                              1.1
# 15             0      False                                              558
# 22             0      False                                         text/css
# 21             0      False                                    svg-world-map
# 20             0      False                                                1
# 19             0      False                                               -9
# 18             0      False                                               -9
# 17             0      False                                              991
# 16             0       True                                             1920
# 14             0      False                                           1529.5
# 1              0      False                                             2754
# 13             0      False                                                1
# 12             0      False                                            false
# 11             0      False                                                0
# 10             0      False                                              0.0
# 9              0      False                                                2
# 8              0      False                                              1.0
# 7              0      False                                          #666666
# 6              0      False                                          #ffffff
# 5              0      False                   1.1.2 (b8e25be833, 2022-02-05)
# 4              0      False                       BlankMap-World_save_as.svg
# 2              0      False                                             1398
# 28             0      False
#
#                                             max_value only_integers
# 3                                                  zw           NaN
# 24  m 997.66,58.73 c 0.493,0.07 0.973,0.02 1.44,-0...           NaN
# 23                                         unxx ua xl           NaN
# 27                                            926.524         False
# 26                                                933         False
# 25                                                  6         False
# 0                                                 1.1         False
# 15                                                558         False
# 22                                           text/css           NaN
# 21                                      svg-world-map           NaN
# 20                                                  1         False
# 19                                                 -9         False
# 18                                                 -9         False
# 17                                                991         False
# 16                                               1920         False
# 14                                             1529.5         False
# 1                                                2754         False
# 13                                                  1         False
# 12                                              false           NaN
# 11                                                  0         False
# 10                                                0.0         False
# 9                                                   2         False
# 8                                                 1.0         False
# 7                                             #666666           NaN
# 6                                             #ffffff           NaN
# 5                      1.1.2 (b8e25be833, 2022-02-05)           NaN
# 4                          BlankMap-World_save_as.svg           NaN
# 2                                                1398         False
# 28                                                              NaN

# %%
mask_series = df.circle_radius.isnull() & ~df.path_class.isnull()
df[mask_series].dropna(axis='columns', how='all')
# Out:
#                 svg_id         path_class  \
# 5           path-ocean            oceanxx
# 8           path-sudan          landxx sd
# 11    path-south-sudan          landxx ss
# 14        path-georgia          landxx ge
# 17       path-abkhazia      limitxx ge xa
# ...                ...                ...
# 2854     path-holy-see          landxx va
# 2858  path-isle-of-man  landxx coastxx im
# 2862         path-guam  landxx coastxx gu
# 2866    path-singapore  landxx coastxx sg
# 2870      path-tokelau  landxx coastxx tk
#
#                                                   svg_d
# 5     m 2178.51,22.652 c 23.09,8.443 46.07,17.268 68...
# 8     m 1489.21,614.522 c 0.31,-0.313 0.36,-0.917 0....
# 11    m 1485.36,624.71 c 0,0.448 -0.13,0.908 -0.13,1...
# 14    m 1584.34,323.668 c 0,-3.863 7.97,-0.314 9.49,...
# 17    m 1584.34,323.668 c 1.64,0.234 2.06,2.064 3.79...
# ...                                                 ...
# 2854  m 1394.48,337.712 -0.1,0.03 -0.11,-0.04 0.1,-0...
# 2858  m 1281.85,233.982 c 0.89,-0.203 2.61,-0.724 3....
# 2862  m 2398.42,584.046 c 0.25,-0.289 1.27,-2.729 1....
# 2866  m 2093.43,686.214 c -0.96,0.252 0.51,2.079 1.8...
# 2870  m 2737.92,782.766 c -0.12,-0.1 0.18,-0.08 -0.1...
#
# [329 rows x 3 columns]

# %%
ending_regex = re.compile(r'path\d+$')
mask_series = df.svg_id.map(lambda x: bool(ending_regex.search(str(x))))
df[mask_series].dropna(axis='columns', how='all')#.sort_values('path_class')
# Out:
# Empty DataFrame
# Columns: []
# Index: []

# %%
print(df.svg_id.unique().tolist())

# %%
df.columns.tolist()

# %% [markdown]
# ----
# # Extract the Paths from the SVG

# %%
# Extract the paths from the SVG
import xml.etree.ElementTree as et
import pandas as pd

file_path = r'C:\Users\daveb\OneDrive\Documents\GitHub\StatsByCountry\saves\svg\BlankMap-World_save_as.svg'
root = et.parse(file_path).getroot()
rows_list = []
for el in root.iter():
    rows_list.append(el.attrib)
df = pd.DataFrame(rows_list).rename(columns={
    'width': 'svg_width',
    '{http://www.inkscape.org/namespaces/inkscape}version': 'inkscape_version',
    'height': 'svg_height',
    'id': 'svg_id',
    '{http://sodipodi.sourceforge.net/DTD/sodipodi-0.dtd}docname': 'sodipodi_docname',
    'version': 'svg_version',
    'viewBox': 'svg_viewBox',
    'bordercolor': 'svg_bordercolor',
    'borderopacity': 'svg_borderopacity',
    '{http://www.inkscape.org/namespaces/inkscape}current-layer': 'inkscape_current_layer',
    '{http://www.inkscape.org/namespaces/inkscape}cx': 'inkscape_cx',
    '{http://www.inkscape.org/namespaces/inkscape}cy': 'inkscape_cy',
    '{http://www.inkscape.org/namespaces/inkscape}pagecheckerboard': 'inkscape_pagecheckerboard',
    '{http://www.inkscape.org/namespaces/inkscape}pageopacity': 'inkscape_pageopacity',
    '{http://www.inkscape.org/namespaces/inkscape}pageshadow': 'inkscape_pageshadow',
    '{http://www.inkscape.org/namespaces/inkscape}window-height': 'inkscape_window_height',
    '{http://www.inkscape.org/namespaces/inkscape}window-maximized': 'inkscape_window_maximized',
    '{http://www.inkscape.org/namespaces/inkscape}window-width': 'inkscape_window_width',
    '{http://www.inkscape.org/namespaces/inkscape}window-x': 'inkscape_window_x',
    '{http://www.inkscape.org/namespaces/inkscape}window-y': 'inkscape_window_y',
    '{http://www.inkscape.org/namespaces/inkscape}zoom': 'inkscape_zoom',
    'pagecolor': 'svg_pagecolor',
    'showgrid': 'svg_showgrid',
    'type': 'svg_type',
    'd': 'svg_d',
    'style': 'svg_style',
    '{http://www.inkscape.org/namespaces/inkscape}connector-curvature': 'inkscape_connector_curvature',
    '{http://www.w3.org/1999/02/22-rdf-syntax-ns#}about': 'rdf_about',
    '{http://www.w3.org/1999/02/22-rdf-syntax-ns#}resource': 'rdf_resource',
    'x': 'svg_x',
    'y': 'svg_y',
    '{http://www.inkscape.org/namespaces/inkscape}label': 'inkscape_label',
    '{http://sodipodi.sourceforge.net/DTD/sodipodi-0.dtd}insensitive': 'sodipodi_insensitive',
    'data-id': 'svg_data_id',
    'data-name': 'svg_data_name',
    '{http://sodipodi.sourceforge.net/DTD/sodipodi-0.dtd}role': 'sodipodi_role',
    'r': 'circle_radius',
    'cx': 'center_x',
    'cy': 'center_y',
    'class': 'path_class'})

# %%
column_descriptions_df = ssu.get_column_descriptions(df, column_list=None)

# %%
column_descriptions_df.sort_values(['count_uniques'], ascending=[False])
# Out:
#                   column_name   dtype  count_blanks  count_uniques  \
# 3                      svg_id  object             3           2874
# 24                      svg_d  object           663           2212
# 23                 path_class  object          2446            421
# 27                   center_x  object          2773            101
# 26                   center_y  object          2773            101
# 25              circle_radius  object          2773              6
# 0                 svg_version  object          2875              2
# 15                inkscape_cy  object          2875              2
# 22                   svg_type  object          2875              2
# 21     inkscape_current_layer  object          2875              2
# 20  inkscape_window_maximized  object          2875              2
# 19          inkscape_window_y  object          2875              2
# 18          inkscape_window_x  object          2875              2
# 17     inkscape_window_height  object          2875              2
# 16      inkscape_window_width  object          2875              2
# 14                inkscape_cx  object          2875              2
# 1                   svg_width  object          2875              2
# 13              inkscape_zoom  object          2875              2
# 12               svg_showgrid  object          2875              2
# 11  inkscape_pagecheckerboard  object          2875              2
# 10       inkscape_pageopacity  object          2875              2
# 9         inkscape_pageshadow  object          2875              2
# 8           svg_borderopacity  object          2875              2
# 7             svg_bordercolor  object          2875              2
# 6               svg_pagecolor  object          2875              2
# 5            inkscape_version  object          2875              2
# 4            sodipodi_docname  object          2875              2
# 2                  svg_height  object          2875              2
# 28                  rdf_about  object          2875              2
#
#     count_zeroes  has_dates                                        min_value  \
# 3              0      False                                   Angola_Cabinda
# 24             0      False  m 1005.94,815.96 c 1.08,-2.827 -1.86,-0.525 0,0
# 23             0      False                          antxx landxx coastxx aq
# 27             0       True                                              101
# 26             0      False                                          1123.85
# 25             0      False                                             0.25
# 0              0      False                                              1.1
# 15             0      False                                              558
# 22             0      False                                         text/css
# 21             0      False                                    svg-world-map
# 20             0      False                                                1
# 19             0      False                                               -9
# 18             0      False                                               -9
# 17             0      False                                              991
# 16             0       True                                             1920
# 14             0      False                                           1529.5
# 1              0      False                                             2754
# 13             0      False                                                1
# 12             0      False                                            false
# 11             0      False                                                0
# 10             0      False                                              0.0
# 9              0      False                                                2
# 8              0      False                                              1.0
# 7              0      False                                          #666666
# 6              0      False                                          #ffffff
# 5              0      False                   1.1.2 (b8e25be833, 2022-02-05)
# 4              0      False                       BlankMap-World_save_as.svg
# 2              0      False                                             1398
# 28             0      False
#
#                                             max_value only_integers
# 3                                                  zw           NaN
# 24  m 997.66,58.73 c 0.493,0.07 0.973,0.02 1.44,-0...           NaN
# 23                                         unxx ua xl           NaN
# 27                                            926.524         False
# 26                                                933         False
# 25                                                  6         False
# 0                                                 1.1         False
# 15                                                558         False
# 22                                           text/css           NaN
# 21                                      svg-world-map           NaN
# 20                                                  1         False
# 19                                                 -9         False
# 18                                                 -9         False
# 17                                                991         False
# 16                                               1920         False
# 14                                             1529.5         False
# 1                                                2754         False
# 13                                                  1         False
# 12                                              false           NaN
# 11                                                  0         False
# 10                                                0.0         False
# 9                                                   2         False
# 8                                                 1.0         False
# 7                                             #666666           NaN
# 6                                             #ffffff           NaN
# 5                      1.1.2 (b8e25be833, 2022-02-05)           NaN
# 4                          BlankMap-World_save_as.svg           NaN
# 2                                                1398         False
# 28                                                              NaN

# %%
mask_series = df.circle_radius.isnull() & ~df.path_class.isnull()
df[mask_series].dropna(axis='columns', how='all')
# Out:
#                 svg_id         path_class  \
# 5           path-ocean            oceanxx
# 8           path-sudan          landxx sd
# 11    path-south-sudan          landxx ss
# 14        path-georgia          landxx ge
# 17       path-abkhazia      limitxx ge xa
# ...                ...                ...
# 2854     path-holy-see          landxx va
# 2858  path-isle-of-man  landxx coastxx im
# 2862         path-guam  landxx coastxx gu
# 2866    path-singapore  landxx coastxx sg
# 2870      path-tokelau  landxx coastxx tk
#
#                                                   svg_d
# 5     m 2178.51,22.652 c 23.09,8.443 46.07,17.268 68...
# 8     m 1489.21,614.522 c 0.31,-0.313 0.36,-0.917 0....
# 11    m 1485.36,624.71 c 0,0.448 -0.13,0.908 -0.13,1...
# 14    m 1584.34,323.668 c 0,-3.863 7.97,-0.314 9.49,...
# 17    m 1584.34,323.668 c 1.64,0.234 2.06,2.064 3.79...
# ...                                                 ...
# 2854  m 1394.48,337.712 -0.1,0.03 -0.11,-0.04 0.1,-0...
# 2858  m 1281.85,233.982 c 0.89,-0.203 2.61,-0.724 3....
# 2862  m 2398.42,584.046 c 0.25,-0.289 1.27,-2.729 1....
# 2866  m 2093.43,686.214 c -0.96,0.252 0.51,2.079 1.8...
# 2870  m 2737.92,782.766 c -0.12,-0.1 0.18,-0.08 -0.1...
#
# [329 rows x 3 columns]

# %%
ending_regex = re.compile(r'path\d+$')
mask_series = df.svg_id.map(lambda x: bool(ending_regex.search(str(x))))
df[mask_series].dropna(axis='columns', how='all')#.sort_values('path_class')
# Out:
# Empty DataFrame
# Columns: []
# Index: []

# %%
print(df.svg_id.unique().tolist())

# %%
df.columns.tolist()

# %%
# Extract Paths from an SVG
import xml.etree.ElementTree as et
import pandas as pd

file_path = r'C:\Users\daveb\OneDrive\Documents\GitHub\StatsByCountry\saves\svg\Political_map_world_1986-1989_Dutch_save_as.svg'
root = et.parse(file_path).getroot()
rows_list = []
for el in root.iter():
    rows_list.append(el.attrib)
df = pd.DataFrame(rows_list).rename(columns={
    'bordercolor': 'svg_bordercolor',
    'borderopacity': 'svg_borderopacity',
    'class': 'path_class',
    'cx': 'center_x',
    'cy': 'center_y',
    'd': 'svg_d',
    'data-id': 'svg_data_id',
    'data-name': 'svg_data_name',
    'height': 'svg_height',
    'id': 'svg_id',
    'pagecolor': 'svg_pagecolor',
    'r': 'circle_radius',
    'showgrid': 'svg_showgrid',
    'style': 'svg_style',
    'type': 'svg_type',
    'version': 'svg_version',
    'viewBox': 'svg_viewBox',
    'width': 'svg_width',
    'x': 'svg_x',
    'y': 'svg_y',
    '{http://sodipodi.sourceforge.net/DTD/sodipodi-0.dtd}docname': 'sodipodi_docname',
    '{http://sodipodi.sourceforge.net/DTD/sodipodi-0.dtd}insensitive': 'sodipodi_insensitive',
    '{http://sodipodi.sourceforge.net/DTD/sodipodi-0.dtd}nodetypes': 'sodipodi_nodetypes',
    '{http://sodipodi.sourceforge.net/DTD/sodipodi-0.dtd}role': 'sodipodi_role',
    '{http://www.inkscape.org/namespaces/inkscape}connector-curvature': 'inkscape_connector_curvature',
    '{http://www.inkscape.org/namespaces/inkscape}current-layer': 'inkscape_current_layer',
    '{http://www.inkscape.org/namespaces/inkscape}cx': 'inkscape_cx',
    '{http://www.inkscape.org/namespaces/inkscape}cy': 'inkscape_cy',
    '{http://www.inkscape.org/namespaces/inkscape}label': 'inkscape_label',
    '{http://www.inkscape.org/namespaces/inkscape}pagecheckerboard': 'inkscape_pagecheckerboard',
    '{http://www.inkscape.org/namespaces/inkscape}pageopacity': 'inkscape_pageopacity',
    '{http://www.inkscape.org/namespaces/inkscape}pageshadow': 'inkscape_pageshadow',
    '{http://www.inkscape.org/namespaces/inkscape}version': 'inkscape_version',
    '{http://www.inkscape.org/namespaces/inkscape}window-height': 'inkscape_window_height',
    '{http://www.inkscape.org/namespaces/inkscape}window-maximized': 'inkscape_window_maximized',
    '{http://www.inkscape.org/namespaces/inkscape}window-width': 'inkscape_window_width',
    '{http://www.inkscape.org/namespaces/inkscape}window-x': 'inkscape_window_x',
    '{http://www.inkscape.org/namespaces/inkscape}window-y': 'inkscape_window_y',
    '{http://www.inkscape.org/namespaces/inkscape}zoom': 'inkscape_zoom',
    '{http://www.w3.org/1999/02/22-rdf-syntax-ns#}about': 'rdf_about',
    '{http://www.w3.org/1999/02/22-rdf-syntax-ns#}resource': 'rdf_resource',
})

# %%
column_descriptions_df = ssu.get_column_descriptions(df, column_list=None)

# %%
column_descriptions_df.sort_values(['count_uniques'], ascending=[False])
# Out:
#               column_name   dtype  count_blanks  count_uniques  count_zeroes  \
# 1                  svg_id  object             4           3548             0
# 46                  svg_d  object           722           2818             0
# 6                   svg_y  object          2859            398             0
# 5                   svg_x  object          2859            305             0
# 40              svg_style  object            19            201             0
# ..                    ...     ...           ...            ...           ...
# 27      inkscape_window_x  object          3550              2             0
# 28      inkscape_window_y  object          3550              2             0
# 29    inkscape_pageshadow  object          3550              2             0
# 30  inkscape_window_width  object          3550              2             0
# 62              clip-rule  object          3550              2             0
#
#     has_dates                                          min_value  \
# 1       False                                             Capa_1
# 46      False            M 1149.7937,513.8172 1134.322,497.78088
# 6       False                                        -0.76424633
# 5        True                                        -0.40036293
# 40      False  display:inline;fill:#ff7f00;fill-opacity:1;str...
# ..        ...                                                ...
# 27      False                                                 -9
# 28      False                                                 -9
# 29      False                                                  2
# 30       True                                               1920
# 62      False                                            evenodd
#
#                                             max_value only_integers
# 1                                                  yd           NaN
# 46  m 99.635962,1194.2852 c 1.335138,-0.125 2.5109...           NaN
# 6                                           995.67236           NaN
# 5                                           987.63635           NaN
# 40  stroke:#4d4d4d;stroke-width:1;stroke-miterlimi...           NaN
# ..                                                ...           ...
# 27                                                 -9         False
# 28                                                 -9         False
# 29                                                  2         False
# 30                                               1920         False
# 62                                            evenodd           NaN
#
# [63 rows x 9 columns]

# %%
ending_regex = re.compile(r'path\d+$')
mask_series = df.svg_id.map(lambda x: bool(ending_regex.search(str(x))))
df[mask_series].dropna(axis='columns', how='all').sort_values('path_class')
# Out:
#         svg_id                                          svg_style  \
# 42    path2630  fill:#fdbf6f;fill-opacity:1;stroke:#4d4d4d;str...
# 20    path1025         stroke:#4d4d4d;fill:#fb9a99;fill-opacity:1
# 21    path2197         stroke:#4d4d4d;fill:#ff7f00;fill-opacity:1
# 27    path1433  opacity:1;fill:#9359a5;fill-opacity:1;stroke:#...
# 30    path2614  fill:#fdbf6f;fill-opacity:1;stroke:#4d4d4d;str...
# ...        ...                                                ...
# 3518  path5716  fill:#f43f3d;fill-opacity:1;stroke:#4d4d4d;str...
# 3519  path5797  fill:#f43f3d;fill-opacity:1;stroke:#4d4d4d;str...
# 3520  path5799  fill:#f43f3d;fill-opacity:1;stroke:#4d4d4d;str...
# 3521  path5787  fill:#fb9a99;fill-opacity:1;fill-rule:evenodd;...
# 3542  path6401  fill:#f43f3d;fill-opacity:1;stroke:#4d4d4d;str...
#
#      inkscape_connector_curvature stroke-miterlimit  \
# 42                              0               NaN
# 20                            NaN            3.9745
# 21                            NaN            3.9745
# 27                              0            3.9745
# 30                              0               NaN
# ...                           ...               ...
# 3518                            0               NaN
# 3519                            0               NaN
# 3520                            0               NaN
# 3521                            0               NaN
# 3542                            0               NaN
#
#                                                   svg_d sodipodi_nodetypes  \
# 42    m 452.088,523.152 c 6.017,-0.595 12.023,-1.393...                NaN
# 20    M1561.189,584.613c0.098-0.908-0.457-3.063-1.27...                NaN
# 21    M1629.578,562.185c5.873-2.343,11.787-4.586,17....                NaN
# 27    m 1402.9649,615.77337 c 0.506,-1.229 0.705,-2....                NaN
# 30    m 497.737,588.312 c 0.104,0.538 0.296,1.042 0....                NaN
# ...                                                 ...                ...
# 3518  m 1368.5402,306.84328 c 0,0 -0.013,0.0882 0,0....                NaN
# 3519  m 1366.8953,292.6775 c 1.082,-0.136 0.57,-1.16...                NaN
# 3520  m 1371.3663,295.0535 c 0.01,-0.344 -0.042,-0.6...                NaN
# 3521  m 1334.9667,273.78884 c 0,0 0,0.0946 0,0.32443...                NaN
# 3542  m 1672.7563,615.2045 c -2.426,-0.09 -1.0536,-5...                NaN
#
#          fill   stroke transform path_class stroke-width
# 42        NaN      NaN       NaN  landxx mx          NaN
# 20    #B3B3B3  #FFFFFF       NaN        NaN          NaN
# 21    #B3B3B3  #FFFFFF       NaN        NaN          NaN
# 27        NaN      NaN       NaN        NaN          NaN
# 30        NaN      NaN       NaN        NaN          NaN
# ...       ...      ...       ...        ...          ...
# 3518      NaN      NaN       NaN        NaN          NaN
# 3519      NaN      NaN       NaN        NaN          NaN
# 3520      NaN      NaN       NaN        NaN          NaN
# 3521      NaN      NaN       NaN        NaN          NaN
# 3542      NaN      NaN       NaN        NaN          NaN
#
# [2336 rows x 11 columns]
